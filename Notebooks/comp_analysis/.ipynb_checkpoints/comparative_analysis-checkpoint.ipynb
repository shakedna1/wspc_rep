# %%
import sys  
sys.path.insert(0, '../Code')

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sklearn


from matplotlib.font_manager import FontProperties
from shutil import copyfile
from pathlib import Path

import taxa
from data import *
from visualization import *

from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_selection import SelectKBest
from sklearn.model_selection import StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def calculate_results_per_group(test_genomes, preds):
    
    results_dict = {}
    
    for group_name, genomes in test_genomes.groupby(GROUP):
        
        y_test_group = test_genomes.loc[genomes.index][LABEL]
        y_pred = preds.loc[genomes.index][PRED]
        correct = sklearn.metrics.accuracy_score(y_test_group, y_pred, normalize=False)
        accuracy = sklearn.metrics.accuracy_score(y_test_group, y_pred)
        
        print(f'{group_name}\taccuracy={accuracy:.2f} correctly predicted={correct}/{len(y_test_group)}')
        
        if PREDICTION_PROB in preds.columns:
            y_probs = preds.loc[genomes.index][PREDICTION_PROB]
            average_score = np.average(y_probs)
            print(f'Average score={average_score:.2f}')
            
        results_dict[group_name] = accuracy
        
    return results_dict

# %%
def calc_results_all_methods_groups(genomes_metadata, all_methods_preds, methods):
    
    results = {}

    for method in methods:
        
        preds = all_methods_preds.loc[genomes_metadata.index, [method]]
        
        preds.columns = [PRED]
        
        results[method] = calculate_results_per_group(genomes_metadata, preds)
                                                      
    return results

# %%
def report_to_metrics(report):
    
    specificity = round(report['NHP']['recall'], 2)
    sensitivity = round(report['HP']['recall'], 2)
    bacc = round(report['macro avg']['recall'], 2)

    
    return {SPE: specificity, SEN: sensitivity, BACC: bacc}

# %%
def get_cls_results(genomes, all_methods_preds, methods):
    
    results = {}

    for method in methods:
        preds = all_methods_preds.loc[genomes, method]
        labels = all_methods_preds.loc[genomes, LABEL]
        report = classification_report(labels, preds, target_names=TARGET_NAMES, output_dict=True)
        method_results = report_to_metrics(report) 
        results[method] = method_results

    return results

# %%
pd.set_option('display.max_rows', None)

GROUP = 'Group'
GENOME_ID = 'Genome ID'
LABEL = 'Label'

WSPC = 'WSPC'
BACPACS = 'BacPaCS'
PATHOGENFINDER = 'Pathogenfinder'

PRED = 'predictions'
PREDICTION_PROB = 'predictions_probs'

SEN = 'Sensitivity'
SPE = 'Specificity'
BACC = 'BACC'

TARGET_NAMES = ['NHP', 'HP']

# %%
path = Path('..\Data')
predictions_path = path / 'WSPC_test_preds'

train_genomes = MetadataReader.read(path /'train_genomes_info.csv')

test_genome_verified = MetadataReader.read(path / 'test_genomes_verified.csv')
test_genome_verified[LABEL] = test_genome_verified[LABEL].apply(lambda label: GenomesData.label_to_int.get(label))

test_genome_verified.head()
# Out:
#                                        Genome Name  Label HP/NHP  \
# Genome ID
# 163603.4   Actinomadura latina strain ATCC BAA-277      1    1/0
# 648.157           Aeromonas caviae strain ScAc2001      1    9/0
# 565.15         Atlantibacter hermannii strain 3608      1    1/0
# 29459.655    Brucella melitensis strain HN20190002      1   13/0
# 87883.284    Burkholderia multivorans strain C1576      1  107/0
#
#                             Species                     References Group  \
# Genome ID
# 163603.4        Actinomadura latina  \cite{trujillo1997polyphasic}   EHP
# 648.157            Aeromonas caviae              \cite{tang2020co}   EHP
# 565.15      Atlantibacter hermannii  \cite{ioannou2019escherichia}   EHP
# 29459.655       Brucella melitensis         \cite{li2020molecular}   EHP
# 87883.284  Burkholderia multivorans           \cite{silva2016long}   EHP
#
#                      Host Name Isolation Source  \
# Genome ID
# 163603.4   Human, Homo sapiens   arm of patient
# 648.157    Human, Homo sapiens  Watery diarrhea
# 565.15     Human, Homo sapiens       Wound swab
# 29459.655  Human, Homo sapiens              NaN
# 87883.284  Human, Homo sapiens           sputum
#
#                                 Isolation Comments Genome Quality  \
# Genome ID
# 163603.4                                       NaN           Good
# 648.157                                        NaN           Good
# 565.15                                         NaN           Good
# 29459.655                                      NaN           Good
# 87883.284  isolated from a cystic fibrosis patient           Good
#
#           Collection Date                    Date Inserted Other Clinical  \
# Genome ID
# 163603.4              NaN 2020-04-26 17:38:00.943000+00:00            NaN
# 648.157           2019-05 2020-01-31 23:41:12.327000+00:00            NaN
# 565.15               2015 2020-02-07 13:50:54.571000+00:00            NaN
# 29459.655      2019-02-04 2020-01-31 21:07:14.657000+00:00            NaN
# 87883.284            1992 2020-03-27 14:33:49.442000+00:00            NaN
#
#                  Host Health Disease  \
# Genome ID
# 163603.4                 NaN     NaN
# 648.157             Diarrhea     NaN
# 565.15     Wound infection 8     NaN
# 29459.655                NaN     NaN
# 87883.284    Cystic fibrosis     NaN
#
#                                                     Comments
# Genome ID
# 163603.4                                  MicrobeNet genomes
# 648.157    Whole genome sequenced and analysis MDR isolat...
# 565.15     Extended Spectrum beta-lactamase producing Ent...
# 29459.655  strain was obtained from patients in Hainan,China
# 87883.284  Whole genome sequencing of a clinical isolate ...

# %%
test_genome_verified[GROUP].value_counts()
# Out:
# OHP     77
# ENHP    61
# ONHP    41
# EHP     25
# Name: Group, dtype: int64

# %%
all_methods_preds = test_genome_verified[[LABEL]].copy()

# %% [markdown]
# # bacpacs results

# %%
bacpacs_pred_arr = pd.read_csv(predictions_path / 'bacpacs_prediction_on_wspc_test.csv')  
bacpacs_pred_arr['genome_id'] = bacpacs_pred_arr['genome_id'].str.strip('.PATRIC')
bacpacs_pred_arr = bacpacs_pred_arr.set_index('genome_id')

# %%
bacpacs_pred_arr
# Out:
#               predictions
# genome_id
# 104608.5                0
# 104628.50               1
# 109328.8                0
# 1117645.412             1
# 1134687.181             1
# 119602.327              1
# 1202713.3               1
# 1246.49                 0
# 1260.144                0
# 1280.23630              1
# 1282.3805               1
# 1283.793                1
# 1304.1361               0
# 1311.2752               1
# 1313.20171              1
# 1318.781                0
# 133448.15               1
# 1335613.28              0
# 1343.51                 0
# 1351.3480               1
# 1352.8997               0
# 1353.134                0
# 1354.275                0
# 1396.2563               1
# 1423.1028               1
# 1463165.235             1
# 1468449.9               1
# 1491.1756               1
# 1492.181                0
# 1496.5104               1
# 150053.31               1
# 1505.72                 1
# 1507806.57              1
# 1520.337                1
# 1522.125                0
# 1550024.413             0
# 1587.365                0
# 158836.472              1
# 1597.462                1
# 1613.506                0
# 1623.232                0
# 163603.4                1
# 1639.7756               1
# 1648923.136             0
# 165179.2440             0
# 166486.885              0
# 1679.240                0
# 1680.1978               0
# 1681.836                0
# 1689.110                0
# 1720313.7               1
# 1737424.51              1
# 1768.199                1
# 1773.20690              1
# 1809.19                 1
# 1812935.59              0
# 1871037.250             1
# 1872444.542             0
# 1898207.3769            0
# 190721.31               1
# 195.2778                1
# 201.69                  0
# 2026186.33              1
# 2026190.21              0
# 2026720.132             1
# 2044595.31              0
# 2044936.47              0
# 2044938.12              0
# 2045451.27              1
# 2049035.5               0
# 2049039.16              0
# 2053618.40              0
# 208962.153              1
# 2093855.3               0
# 210.6620                1
# 218538.1051             1
# 238.101                 1
# 244366.462              1
# 2494701.5               1
# 2528037.4               0
# 2547410.3               0
# 254785.37               1
# 2572066.4               1
# 257758.659              1
# 2584624.3               0
# 2584625.3               0
# 2584626.3               0
# 2584631.3               0
# 2584634.3               0
# 2584635.3               0
# 2584637.3               0
# 2584641.3               0
# 2584644.3               0
# 2584645.3               0
# 2584653.3               0
# 2584658.3               0
# 2584661.3               0
# 2584670.3               0
# 2584682.3               0
# 2664891.3               1
# 2681497.3               1
# 2681551.3               1
# 2686092.3               1
# 28025.139               0
# 28090.110               0
# 28116.1355              0
# 28118.1621              0
# 28141.803               1
# 28450.2018              1
# 287.11178               1
# 292.237                 1
# 292800.500              0
# 29378.48                1
# 29388.243               1
# 29430.96                1
# 29459.655               1
# 29466.1006              0
# 299767.100              1
# 301302.2226             0
# 328812.119              1
# 33025.448               0
# 33039.1028              0
# 33945.49                1
# 35703.89                0
# 36809.633               1
# 371601.509              1
# 39485.1649              0
# 39490.144               0
# 39491.2484              0
# 39778.876               0
# 40324.1544              1
# 40518.2573              0
# 40520.1620              0
# 40545.1254              0
# 410072.542              1
# 413501.15               0
# 413502.35               1
# 413503.68               1
# 418240.274              1
# 419475.21               0
# 44250.11                0
# 44275.61                1
# 44737.7                 1
# 455432.12               1
# 46503.1849              1
# 46680.55                1
# 470.9648                1
# 471189.25               0
# 47715.653               1
# 480.450                 1
# 48296.376               1
# 485.8128                1
# 487.3238                1
# 487175.63               0
# 492670.508              1
# 53345.154               0
# 53346.66                0
# 539.170                 1
# 54291.261               1
# 545.121                 1
# 546.797                 1
# 548.678                 1
# 550.2644                0
# 562.55247               1
# 565.15                  1
# 571.798                 1
# 571933.10               1
# 573.29103               1
# 575.68                  1
# 57706.80                1
# 582.399                 1
# 584.1255                1
# 585.92                  1
# 588.149                 1
# 592978.29               0
# 59823.699               0
# 615.1093                1
# 61645.317               1
# 624.2242                1
# 648.157                 1
# 648995.31               1
# 65058.433               1
# 67824.24                1
# 67827.42                1
# 686.65                  1
# 71452.14                0
# 727.2505                1
# 729.1932                0
# 74426.1601              0
# 753.7                   1
# 78331.108               1
# 79880.75                1
# 817.1653                1
# 818.1282                0
# 820.4961                1
# 821.3918                0
# 823.3208                0
# 853.7356                0
# 85698.208               0
# 87883.284               1
# 88431.891               0
# 90370.3046              1
# 948102.18               1
# 95486.460               1

# %%
print('BacPaCS results:')

bacpacs_results = calculate_results_per_group(test_genome_verified, bacpacs_pred_arr)
# Out:
# BacPaCS results:
# EHP	accuracy=0.96 correctly predicted=24/25
# ENHP	accuracy=0.72 correctly predicted=44/61
# OHP	accuracy=0.82 correctly predicted=63/77
# ONHP	accuracy=0.73 correctly predicted=30/41

# %%
all_methods_preds.loc[bacpacs_pred_arr.index, BACPACS] = bacpacs_pred_arr[PRED]
all_methods_preds.head()
# Out:
#            Label  BacPaCS
# Genome ID
# 163603.4       1        1
# 648.157        1        1
# 565.15         1        1
# 29459.655      1        1
# 87883.284      1        1

# %% [markdown]
# # pathogenfinder results

# %%
folder = predictions_path / 'results pathogenfinder'
files = os.listdir(folder)
pathogenfinder_preds = pd.DataFrame(index = test_genome_verified.index, columns = ['predictions'], dtype=int)

for name in files:
    if name.startswith('PathogenFinder_cdhit_raw'): continue
        
    genome_id = name.split('.txt', 1)[0].split('_')[2]
    if genome_id in  test_genome_verified.index:
            with open(folder / name , 'r') as input_file:
                for line in input_file: 
                    if line.startswith('The organisms is predicted as human pathogenic ::'):
                        predicted_pathogen = line.strip().split('\t')[1]
                        if predicted_pathogen == 'Yes': pathogenfinder_preds.at[genome_id, 'predictions'] = 1
                        elif predicted_pathogen == 'No': pathogenfinder_preds.at[genome_id, 'predictions'] = 0
                        else: print(f'Error in results of file: {name}')
                    # Validate that the file name match the input sequence
                    if line.startswith('#input_seq:'):
                        seq_id =  line.split('fig|')[1].split('.peg')[0]
                        if genome_id != seq_id: print(f'Error in file name: {name}')
                        break

# %%
pathogenfinder_preds.head()
# Out:
#            predictions
# Genome ID
# 163603.4           0.0
# 648.157            1.0
# 565.15             1.0
# 29459.655          1.0
# 87883.284          1.0

# %%
all_methods_preds.loc[pathogenfinder_preds.index, PATHOGENFINDER] = pathogenfinder_preds[PRED]

# %%
all_methods_preds.head()
# Out:
#            Label  BacPaCS  Pathogenfinder
# Genome ID
# 163603.4       1        1             0.0
# 648.157        1        1             1.0
# 565.15         1        1             1.0
# 29459.655      1        1             1.0
# 87883.284      1        1             1.0

# %%
print('Pathogenfinder results:')
pathogenfinder_results = calculate_results_per_group(test_genome_verified, pathogenfinder_preds)
# Out:
# Pathogenfinder results:
# EHP	accuracy=0.96 correctly predicted=24/25
# ENHP	accuracy=0.59 correctly predicted=36/61
# OHP	accuracy=0.86 correctly predicted=66/77
# ONHP	accuracy=0.29 correctly predicted=12/41

# %% [markdown]
# # WSPC results

# %%
wspc_preds = pd.read_csv(predictions_path / 'wspc_test_preds.csv', 
                         dtype={GENOME_ID: str}).set_index(GENOME_ID)

# %%
all_methods_preds.loc[wspc_preds.index, WSPC] = wspc_preds[PRED]

# %%
all_methods_preds.head()
# Out:
#            Label  BacPaCS  Pathogenfinder  WSPC
# Genome ID
# 163603.4       1        1             0.0     1
# 648.157        1        1             1.0     1
# 565.15         1        1             1.0     1
# 29459.655      1        1             1.0     1
# 87883.284      1        1             1.0     1

# %%
wspc_results = calculate_results_per_group(test_genome_verified, wspc_preds)
# Out:
# EHP	accuracy=1.00 correctly predicted=25/25
# Average score=0.94
# ENHP	accuracy=0.93 correctly predicted=57/61
# Average score=0.13
# OHP	accuracy=0.92 correctly predicted=71/77
# Average score=0.90
# ONHP	accuracy=0.59 correctly predicted=24/41
# Average score=0.43

# %% [markdown]
# # Comparative plots

# %%
figs_output = Path('..\Paper\Figures')

# %%
bar_groups = ['EHP', 'ENHP', 'OHP', 'ONHP']
methods = [WSPC, BACPACS, PATHOGENFINDER]

out_path = figs_output / 'comparative_wspc_test_groups.pdf'

results = calc_results_all_methods_groups(test_genome_verified, all_methods_preds, methods)

create_grouped_barplots(results, bar_groups, bars, out_path, bar_width=0.24, fig_size=(9, 5), y_label='Accuracy',
                            x_ticks_font_size=20, legend_loc='upper right')
# Out:
# EHP	accuracy=1.00 correctly predicted=25/25
# ENHP	accuracy=0.93 correctly predicted=57/61
# OHP	accuracy=0.92 correctly predicted=71/77
# ONHP	accuracy=0.59 correctly predicted=24/41
# EHP	accuracy=0.96 correctly predicted=24/25
# ENHP	accuracy=0.72 correctly predicted=44/61
# OHP	accuracy=0.82 correctly predicted=63/77
# ONHP	accuracy=0.73 correctly predicted=30/41
# EHP	accuracy=0.96 correctly predicted=24/25
# ENHP	accuracy=0.59 correctly predicted=36/61
# OHP	accuracy=0.86 correctly predicted=66/77
# ONHP	accuracy=0.29 correctly predicted=12/41

# %%
fig_name = 'Comparative_wspc_test_general.pdf'
out_path = figs_output / fig_name

measures = [BACC, SEN, SPE]

general_results = get_cls_results(all_methods_preds.index, all_methods_preds, all_methods_preds.columns)

create_grouped_barplots(general_results, bar_groups=measures, bars=methods, out_path=out_path, bar_width=0.24, fig_size=(9, 5))

# %% [markdown]
# novel species

# %%
novel_species = taxa.get_novel_species(train_genomes.index, test_genome_verified.index)
novel_species_genomes = taxa.get_genomes_with_tax(test_genome_verified.index, novel_species, taxa.SPECIES)

# %%
fig_name = 'Comparative_wspc_test_novel_species.pdf'
out_path = figs_output / fig_name

novel_sepcies_results = get_cls_results(novel_species_genomes, all_methods_preds, methods)

create_grouped_barplots(novel_sepcies_results, bar_groups=measures, bars=methods, out_path=out_path, bar_width=0.24, 
                        fig_size=(9, 5))

# %%
results = calc_results_all_methods_groups(test_genome_verified.loc[novel_species_genomes, :], all_methods_preds, methods)

bar_groups = ['EHP', 'ENHP', 'OHP', 'ONHP']
bars = [WSPC, BACPACS, PATHOGENFINDER]

out_path = figs_output / 'comparative_wspc_test_groups_novel_species.pdf'

create_grouped_barplots(results, bar_groups, bars, out_path, bar_width=0.24, fig_size=(9, 5), y_label='Accuracy',
                            x_ticks_font_size=20, legend_loc='upper right')
# Out:
# EHP	accuracy=1.00 correctly predicted=5/5
# ENHP	accuracy=0.89 correctly predicted=17/19
# OHP	accuracy=0.78 correctly predicted=21/27
# ONHP	accuracy=0.58 correctly predicted=7/12
# EHP	accuracy=0.80 correctly predicted=4/5
# ENHP	accuracy=0.53 correctly predicted=10/19
# OHP	accuracy=0.67 correctly predicted=18/27
# ONHP	accuracy=0.58 correctly predicted=7/12
# EHP	accuracy=0.80 correctly predicted=4/5
# ENHP	accuracy=0.68 correctly predicted=13/19
# OHP	accuracy=0.81 correctly predicted=22/27
# ONHP	accuracy=0.17 correctly predicted=2/12
