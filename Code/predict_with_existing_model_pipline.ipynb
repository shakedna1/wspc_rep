# %%
import json
import pickle


import util
import train_and_predict
import feature_importance

# %%
classifier = util.load_model('wspc_classifier.pkl')
y_test =  util.create_labels_df('test_genomes_information.csv')
predictions, predictions_probs = train_and_predict.predict_with_existing_model(classifier, 'wspc_classifier_features.json', 'test_genomes.fasta', 'tmp_genomes')
# Out:
# Creating features vectors..
# Creating features vectors - Done
#
# ***** Predictions ******
# Genome ID: 2584637.3:, prediction: NHP
# Genome ID: 1522.120:, prediction: NHP
# Genome ID: 1280.24245:, prediction: HP
# Genome ID: 254785.37:, prediction: HP
# Genome ID: 1117645.412:, prediction: HP
# Genome ID: 686.84:, prediction: HP
# Genome ID: 648.157:, prediction: HP
# Genome ID: 54291.261:, prediction: HP
# Genome ID: 29459.655:, prediction: HP
# Genome ID: 1311.2752:, prediction: HP
# Genome ID: 238.101:, prediction: HP
# Genome ID: 210.6620:, prediction: HP
# Genome ID: 2584656.3:, prediction: NHP
# Genome ID: 1246.49:, prediction: NHP
# Genome ID: 287.11178:, prediction: HP
# Genome ID: 2494701.5:, prediction: HP
# Genome ID: 67827.33:, prediction: HP
# Genome ID: 1613.506:, prediction: NHP
# Genome ID: 2681497.3:, prediction: HP
# Genome ID: 948102.18:, prediction: HP
# Genome ID: 150053.31:, prediction: HP
# Genome ID: 87883.284:, prediction: HP
# ...
